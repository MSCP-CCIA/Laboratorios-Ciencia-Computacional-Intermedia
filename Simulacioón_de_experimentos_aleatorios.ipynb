# %% [markdown]
# <a href="https://colab.research.google.com/github/MSCP-CCIA/Laboratorios-Ciencia-Computacional-Intermedia/blob/main/Simulacio%C3%B3n_de_experimentos_aleatorios.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from numpy.typing import ArrayLike
from collections import Counter
from typing import Dict, List, Tuple
from IPython.display import display

# %%
def probabilitySimulator(amount: int) -> float:
  exitos = [(x, y) for _ in range(amount) if (x := np.random.uniform(0, 60)) - (y := np.random.uniform(0, 60)) <= 10]
  datos = [(x, y) for _ in range(amount) if (x := np.random.uniform(0, 60)) - (y := np.random.uniform(0, 60)) > 10]
  return exitos, datos
exitos, datos = probabilitySimulator(10000)

# %%
print('probabilidad estimada =', len(exitos) / 10000 )
plt.scatter([x for x, _ in datos], [y for _, y  in datos])
plt.scatter([x for x, _ in exitos], [y for _, y  in exitos])
# Out:
# probabilidad estimada = 0.6571

# %%
n = 10000

exito = 0

datos = []
exitos = []

for _ in range(n):

    x = np.random.uniform(0, 60)
    y = np.random.uniform(0, 60)

    if np.abs(x - y) <= 10:
        exitos.append((x, y))
    else:
        datos.append((x, y))

print('probabilidad estimada =', len(exitos) / n )

plt.scatter([x for x, _ in datos], [y for _, y  in datos])
plt.scatter([x for x, _ in exitos], [y for _, y  in exitos])
# Out:
# probabilidad estimada = 0.3026
